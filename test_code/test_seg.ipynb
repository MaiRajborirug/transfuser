# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

end = '0050.png'
main_path = '/media/haoming/970EVO/Pharuj/transfuser_data/coke_dataset_23_11/Routes_Scenario3_Town07_curved_Seed1000/Scenario3_Town07_curved_route6_11_23_20_24_14'
img_path = os.path.join(main_path, 'rgb', end)
seg_path = os.path.join(main_path, 'semantics', end)

# %%
from PIL import Image

# regular img
image = Image.open(img_path)
data = np.asarray(image)
imgplot = plt.imshow(data)
plt.show()

# segmentation label
seg = Image.open(seg_path)
data2 = np.asarray(seg)
imgplot = plt.imshow(data2)
plt.show()

# mask label
c = [22]
# Set pixel values to 1 if they are in the list c, otherwise set them to 0
data3 = np.where(np.isin(data2, c), 1, 0)
imgplot = plt.imshow(data3)
plt.show()

print(np.unique(data2))
print(np.unique(data3))
# Out:
# [ 1  2  3  5  6  7  9 10 12 13 22]
# [0 1]

# %%
        # Set elements to 1 based on your criteria
        # 3 = other
        is_road[np.isin(output, [6, 7, 13, 14, 15, 16])] = 1
        is_nonanimated[np.isin(output, [1, 2, 3, 5, 8, 9, 11, 17, 22])] = 1
        is_terrain[np.isin(output, [22])] = 1
        is_animated[np.isin(output, [4, 10, ])] = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6518/3622038434.py in <module>
#       1 # Set elements to 1 based on your criteria
#       2 # 3 = other
# ----> 3 is_road[np.isin(output, [6, 7, 13, 14, 15, 16])] = 1
#       4 is_nonanimated[np.isin(output, [1, 2, 3, 5, 8, 9, 11, 17, 22])] = 1
#       5 is_terrain[np.isin(output, [22])] = 1
#
# NameError: name 'is_road' is not defined
